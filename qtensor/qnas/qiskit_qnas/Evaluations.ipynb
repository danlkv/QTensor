# %%
from qiskit import qpy

# %%
# !ls checkpoints/rs/*
# Out:
# checkpoints/best_energies_graph_1.pkl  checkpoints/graph_model18.qpy
# checkpoints/graph_model0.qpy	       checkpoints/graph_model19.qpy
# checkpoints/graph_model1.qpy	       checkpoints/graph_model2.qpy
# checkpoints/graph_model10.qpy	       checkpoints/graph_model3.qpy
# checkpoints/graph_model11.qpy	       checkpoints/graph_model4.qpy
# checkpoints/graph_model12.qpy	       checkpoints/graph_model5.qpy
# checkpoints/graph_model13.qpy	       checkpoints/graph_model6.qpy
# checkpoints/graph_model14.qpy	       checkpoints/graph_model7.qpy
# checkpoints/graph_model15.qpy	       checkpoints/graph_model8.qpy
# checkpoints/graph_model16.qpy	       checkpoints/graph_model9.qpy
# checkpoints/graph_model17.qpy

# %%
"""
graph = sample(G)
ckt_samples = []
p = 1
for i : 1->150:
    ckt_sampling[i] = random_circuit_sampling()
    best_energy = train_ckt(ckt_sampling[i], iters=2500, COBYLA)
    ckt_sampling[i].energy = best_energy

best_circuit = sort(ckt_sampling)[0], key: best_energy / classical_energy
mlp = MLP(ckt_sampling, energy)



for e in epochs:
    // parallelized
    for ckt in best_ckt_array:
        perf = measure(G, ckt)
    
    best_circuit = best(perf_array)
    new_arch = mutate(best_circuit)
    mlp(new_arch) = performance
    update_population()
    
"""

# %%
with open('checkpoints/graph_model19.qpy', 'rb') as infile:
    qmodel = qpy.load(infile)

# %%
qmodel[0].draw("mpl")
